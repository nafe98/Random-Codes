# %%
This is an example code. I will provide dataset, you have to implement those data to this code and change the titles accordingly. but do not change the code

# %%
# Importing necessary libraries for data visualization and manipulation
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Configuring global font settings for consistent visual presentation
plt.rcParams['font.family'] = 'Times New Roman'  # Set font family to Times New Roman
plt.rcParams['font.style'] = 'normal'  # Disable italics
plt.rcParams['font.size'] = 16  # Set global font size to 16

# Data representing accuracy scores for various machine learning models across different feature sets
data = {
    'Feature': ['Feature 5', 'Feature 8', 'Feature 16', 'Feature 22', 'Feature 27', 'All Features'],
    'KNN': [0.91, 0.98, 1.00, 1.00, 1.00, 1.00],
    'Random Forest': [1.00, 1.00, 1.00, 1.00, 1.00, 1.00],
    'XGBoost': [0.78, 0.86, 0.95, 0.97, 0.98, 0.98],
    'Decision Tree': [1.00, 1.00, 1.00, 1.00, 1.00, 1.00],
    'Extra Trees': [1.00, 1.00, 1.00, 1.00, 1.00, 1.00]
}

# Converting the dictionary into a pandas DataFrame for structured data manipulation
df = pd.DataFrame(data)

# Reshaping the DataFrame to long format, facilitating compatibility with Seaborn's plotting functions
df_melted = df.melt(id_vars='Feature', var_name='Model', value_name='Accuracy')

# Configuring Seaborn aesthetics for clean and professional visualizations
sns.set(style="whitegrid")

# Generating a boxplot to visualize the accuracy distribution of different models across feature sets
plt.figure(figsize=(10, 6))
sns.boxplot(x='Model', y='Accuracy', data=df_melted, hue='Model', palette='viridis')

# Adding descriptive plot title and axis labels using a professional font and size
plt.title('Model Accuracy Comparison Across Various Feature Sets', fontsize=16, fontweight='bold')
plt.xlabel('Machine Learning Model', fontsize=20, fontweight='bold', labelpad=15)
plt.ylabel('Accuracy', fontsize=20, fontweight='bold', labelpad=15)

# Formatting x-axis labels for better readability and ensuring appropriate tick sizes for both axes
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# Optimizing the layout to ensure clarity and prevent overlap of labels and plot elements
plt.tight_layout()

# Saving the resulting figure in a high-resolution PNG format for publication
plt.savefig('model_accuracy_comparison.png', format='png', dpi=300)

# Displaying the plot to verify the results visually
plt.show()

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Data representing accuracy scores for various models
data = {
    'Model': ['XGB', 'DT', 'RF', 'ET', 'KNN', 'ANN', 'GRU', 'LSTM', 'Meta'],
    'Accuracy': [0.92, 0.90, 0.98, 0.99, 0.99, 0.99, 0.87, 0.75, 0.99],
    'Category': ['Machine Learning'] * 5 + ['Deep Learning'] * 4
}

# Creating a pandas DataFrame from the data
df = pd.DataFrame(data)

# Setting the plot style for a clean, professional look
sns.set(style="whitegrid")

# Creating a bar plot for model accuracy categorized by Machine Learning and Deep Learning models
plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='Accuracy', data=df, hue='Category', palette='Blues')

# Adding plot title and axis labels in Times New Roman font
plt.title('Comparison of Accuracy for Machine Learning and Deep Learning Models', fontsize=16, fontname='Times New Roman')
plt.xlabel('Model', fontsize=14, fontname='Times New Roman', labelpad=10)
plt.ylabel('Accuracy', fontsize=14, fontname='Times New Roman', labelpad=10)

# Removing minor ticks and customizing major grid for improved clarity
plt.grid(True, which='major', axis='y', linestyle='--', linewidth=0.7, color='gray')
plt.minorticks_off()

# Setting x and y axis tick font sizes
plt.xticks(fontsize=12, fontname='Times New Roman')
plt.yticks(fontsize=12, fontname='Times New Roman')

# Adjusting layout to prevent label overlap
plt.tight_layout()

# Saving the figure in a lossless PDF format (best for research journals)
plt.savefig('model_accuracy_barplot_journal.pdf', format='pdf', dpi=300)

# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Configure global font settings for consistent visual presentation
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 16
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14

# Data representing accuracy scores for various machine learning models across different feature sets
data = {
    'Feature': ['Feature 5', 'Feature 8', 'Feature 16', 'Feature 22', 'Feature 27', 'All Features'],
    'KNN': [0.91, 0.98, 1.00, 1.00, 1.00, 1.00],
    'Random Forest': [1.00, 1.00, 1.00, 1.00, 1.00, 1.00],
    'XGBoost': [0.78, 0.86, 0.95, 0.97, 0.98, 0.98],
    'Decision Tree': [1.00, 1.00, 1.00, 1.00, 1.00, 1.00],
    'Extra Trees': [1.00, 1.00, 1.00, 1.00, 1.00, 1.00]
}

# Convert dictionary into pandas DataFrame
df = pd.DataFrame(data)

# Reshape DataFrame to long format for Seaborn compatibility
df_melted = df.melt(id_vars='Feature', var_name='Model', value_name='Accuracy')

# Configure Seaborn aesthetics for research-level visuals
sns.set(style="whitegrid", context="talk")  # White grid, 'talk' context for larger font sizes
palette = sns.color_palette("viridis", n_colors=len(df.columns) - 1)  # Viridis palette for colorblind-friendly colors

# Create line plot for accuracy comparison
plt.figure(figsize=(10, 7))
sns.lineplot(x='Feature', y='Accuracy', hue='Model', data=df_melted, marker='o', linewidth=2.5, palette=palette)

# Add plot title and axis labels
plt.title('Accuracy of Machine Learning Models Across Feature Sets', fontsize=20, fontweight='bold')
plt.xlabel('Feature Set', fontsize=18, labelpad=15)
plt.ylabel('Accuracy', fontsize=18, labelpad=15)

# Gridlines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Customize legend inside the plot for a professional look
plt.legend(title='Model', loc='lower right', fontsize=14)

# Adjust layout to prevent overlap and improve appearance
plt.tight_layout()

# Save as a high-quality PDF (vector format) for research publication
plt.savefig('model_accuracy_comparison_research.pdf', format='pdf', dpi=300)

# Display the plot
plt.show()

# %%
# Importing necessary libraries for data visualization and manipulation
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Configuring global font settings for consistent visual presentation
plt.rcParams['font.family'] = 'Times New Roman'  # Set font family to Times New Roman
plt.rcParams['font.style'] = 'normal'  # Disable italics
plt.rcParams['font.size'] = 16  # Set global font size to 16

# Data representing accuracy scores for various machine learning models across different feature sets
data = {
    'Feature': ['Feature 5', 'Feature 8', 'Feature 16', 'Feature 22', 'Feature 27', 'All Features'],
    'KNN': [0.91, 0.98, 1.00, 1.00, 1.00, 1.00],
    'Random Forest': [1.00, 1.00, 1.00, 1.00, 1.00, 1.00],
    'XGBoost': [0.78, 0.86, 0.95, 0.97, 0.98, 0.98],
    'Decision Tree': [1.00, 1.00, 1.00, 1.00, 1.00, 1.00],
    'Extra Trees': [1.00, 1.00, 1.00, 1.00, 1.00, 1.00]
}

# Converting the dictionary into a pandas DataFrame for structured data manipulation
df = pd.DataFrame(data)

# Reshaping the DataFrame to long format, facilitating compatibility with Seaborn's plotting functions
df_melted = df.melt(id_vars='Feature', var_name='Model', value_name='Accuracy')

# Configuring Seaborn aesthetics for clean and professional visualizations
sns.set(style="whitegrid")

# Generating a boxplot to visualize the accuracy distribution of different models across feature sets
plt.figure(figsize=(10, 6))
sns.boxplot(x='Model', y='Accuracy', data=df_melted, hue='Model', palette='Blues')  # Updated color palette to 'Blues'

# Adding descriptive plot title and axis labels using a professional font and size
plt.title('Model Accuracy Comparison Across Various Feature Sets', fontsize=16, fontweight='bold')
plt.xlabel('Machine Learning Model', fontsize=20, fontweight='bold', labelpad=15)
plt.ylabel('Accuracy', fontsize=20, fontweight='bold', labelpad=15)

# Formatting x-axis labels for better readability and ensuring appropriate tick sizes for both axes
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# Optimizing the layout to ensure clarity and prevent overlap of labels and plot elements
plt.tight_layout()

# Saving the resulting figure in a high-resolution PNG format for publication
plt.savefig('model_accuracy_comparison.png', format='png', dpi=300)

# Displaying the plot to verify the results visually
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Configure global font settings for consistent visual presentation
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 16
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14

# Data representing mean F1-Score for various models across different feature sets
data = {
    'Feature': ['Feature 5', 'Feature 8', 'Feature 16', 'Feature 22', 'Feature 27', 'All Features'],
    'XGBoost': [0.72, 0.81, 0.92, 0.94, 0.95, 0.96],
    'Decision Tree': [0.74, 0.84, 0.90, 0.91, 0.91, 0.91],
    'Random Forest': [0.83, 0.93, 0.98, 0.99, 0.99, 0.99],
    'Extra Trees': [0.83, 0.93, 0.99, 0.99, 0.99, 0.99],
    'KNN': [0.84, 0.95, 0.99, 1.00, 1.00, 1.00],
    'ANN': [0.87, 0.99, 0.99, 0.99, 0.99, 0.99],
    'GRU': [0.88, 0.98, 0.87, 0.77, 0.86, 0.81],
    'LSTM': [0.88, 0.98, 0.74, 0.79, 0.66, 0.67],
    'Meta Learning': [0.90, 0.99, 0.99, 0.99, 0.99, 0.99]
}

# Convert dictionary into pandas DataFrame
df = pd.DataFrame(data)

# Reshape DataFrame to long format for Seaborn compatibility
df_melted = df.melt(id_vars='Feature', var_name='Model', value_name='Mean F1-Score')

# Configure Seaborn aesthetics for research-level visuals
sns.set(style="whitegrid", context="talk")  # White grid, 'talk' context for larger font sizes

# Use the 'viridis' color palette for better aesthetics
palette = sns.color_palette("viridis", n_colors=len(df.columns) - 1)

# Create line plot for mean F1-score comparison
plt.figure(figsize=(10, 7))
sns.lineplot(x='Feature', y='Mean F1-Score', hue='Model', data=df_melted, marker='o', linewidth=2.5, palette=palette)

# Add plot title and axis labels
plt.title('Mean F1-Score of Models Across Feature Sets', fontsize=20, fontweight='bold')
plt.xlabel('Feature Set', fontsize=18, labelpad=15)
plt.ylabel('Mean F1-Score', fontsize=18, labelpad=15)

# Gridlines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Move the legend to the bottom of the plot
plt.legend(title='Model', loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fontsize=14)

# Adjust layout to prevent overlap and improve appearance
plt.tight_layout()

# Add extra space between the plot and the legend to avoid overlap
plt.subplots_adjust(bottom=0.2)

# Save as a high-quality PNG for research publication
plt.savefig('mean_f1_score_comparison_research_updated.png', format='png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Configure global font settings for consistent visual presentation
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 16
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14

# Data representing mean F1-Score for various models across different feature sets
data = {
    'Feature': ['Feature 5', 'Feature 8', 'Feature 16', 'Feature 22', 'Feature 27', 'All Features'],
    'XGBoost': [0.72, 0.81, 0.92, 0.94, 0.95, 0.96],
    'Decision Tree': [0.74, 0.84, 0.90, 0.91, 0.91, 0.91],
    'Random Forest': [0.83, 0.93, 0.98, 0.99, 0.99, 0.99],
    'Extra Trees': [0.83, 0.93, 0.99, 0.99, 0.99, 0.99],
    'KNN': [0.84, 0.95, 0.99, 1.00, 1.00, 1.00],
    'ANN': [0.87, 0.99, 0.99, 0.99, 0.99, 0.99],
    'GRU': [0.88, 0.98, 0.87, 0.77, 0.86, 0.81],
    'LSTM': [0.88, 0.98, 0.74, 0.79, 0.66, 0.67],
    'Meta Learning': [0.90, 0.99, 0.99, 0.99, 0.99, 0.99]
}

# Convert dictionary into pandas DataFrame
df = pd.DataFrame(data)

# Reshape DataFrame to long format for Seaborn compatibility
df_melted = df.melt(id_vars='Feature', var_name='Model', value_name='Mean F1-Score')

# Configure Seaborn aesthetics for research-level visuals
sns.set(style="whitegrid", context="talk")  # White grid, 'talk' context for larger font sizes

# Use the 'tab10' color palette to ensure distinct colors for each model
palette = sns.color_palette("tab10", n_colors=len(df.columns) - 1)

# Create line plot for mean F1-score comparison
plt.figure(figsize=(10, 7))
sns.lineplot(x='Feature', y='Mean F1-Score', hue='Model', data=df_melted, marker='o', linewidth=2.5, palette=palette)

# Add plot title and axis labels
plt.title('Mean F1-Score of Models Across Feature Sets', fontsize=20, fontweight='bold')
plt.xlabel('Feature Set', fontsize=18, labelpad=15)
plt.ylabel('Mean F1-Score', fontsize=18, labelpad=15)

# Gridlines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Move the legend to the bottom of the plot
plt.legend(title='Model', loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fontsize=14)

# Adjust layout to prevent overlap and improve appearance
plt.tight_layout()

# Add extra space between the plot and the legend to avoid overlap
plt.subplots_adjust(bottom=0.2)

# Save as a high-quality PNG for research publication
plt.savefig('mean_f1_score_comparison_research_updated.png', format='png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Configure global font settings for consistent visual presentation
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 16
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14

# Data representing mean F1-Score for various models across different feature sets
data = {
    'Feature': ['Feature 5', 'Feature 8', 'Feature 16', 'Feature 22', 'Feature 27', 'All Features'],
    'XGBoost': [0.72, 0.81, 0.92, 0.94, 0.95, 0.96],
    'Decision Tree': [0.74, 0.84, 0.90, 0.91, 0.91, 0.91],
    'Random Forest': [0.83, 0.93, 0.98, 0.99, 0.99, 0.99],
    'Extra Trees': [0.83, 0.93, 0.99, 0.99, 0.99, 0.99],
    'KNN': [0.84, 0.95, 0.99, 1.00, 1.00, 1.00],
    'ANN': [0.87, 0.99, 0.99, 0.99, 0.99, 0.99],
    'GRU': [0.88, 0.98, 0.87, 0.77, 0.86, 0.81],
    'LSTM': [0.88, 0.98, 0.74, 0.79, 0.66, 0.67],
    'Meta Learning': [0.90, 0.99, 0.99, 0.99, 0.99, 0.99]
}

# Convert dictionary into pandas DataFrame
df = pd.DataFrame(data)

# Reshape DataFrame to long format for Seaborn compatibility
df_melted = df.melt(id_vars='Feature', var_name='Model', value_name='Mean F1-Score')

# Configure Seaborn aesthetics for research-level visuals
sns.set(style="whitegrid", context="talk")  # White grid, 'talk' context for larger font sizes

# Use a more sophisticated palette and introduce different line styles
palette = sns.color_palette("Spectral", n_colors=len(df.columns) - 1)
line_styles = ['-', '--', '-.', ':', '-', '--', '-.', ':', '-']  # Different line styles
markers = ['o', 's', 'D', 'v', '^', 'X', 'P', '*', 'p']  # Different markers

# Create figure and axis
plt.figure(figsize=(12, 8))

# Create line plot for mean F1-score comparison
for i, model in enumerate(df.columns[1:]):
    sns.lineplot(
        x='Feature', 
        y='Mean F1-Score', 
        data=df_melted[df_melted['Model'] == model], 
        label=model, 
        marker=markers[i], 
        linewidth=2.5, 
        linestyle=line_styles[i],
        palette=palette
    )

# Add plot title and axis labels
plt.title('Mean F1-Score of Models Across Feature Sets', fontsize=22, fontweight='bold', pad=20)
plt.xlabel('Feature Set', fontsize=18, labelpad=15)
plt.ylabel('Mean F1-Score', fontsize=18, labelpad=15)

# Enhance grid for better readability
plt.grid(True, which='major', linestyle='--', linewidth=0.8)
plt.grid(True, which='minor', linestyle=':', linewidth=0.5)

# Move the legend to the bottom of the plot with a box style
plt.legend(title='Model', loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3, fontsize=14, frameon=True, shadow=True)

# Adjust layout to prevent overlap and improve appearance
plt.tight_layout()

# Add extra space between the plot and the legend to avoid overlap
plt.subplots_adjust(bottom=0.25)

# Save as a high-quality PNG for research publication
plt.savefig('mean_f1_score_comparison_sophisticated.png', format='png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()
# Out:
# C:\Users\nafem\AppData\Local\Temp\ipykernel_8784\1015887474.py:47: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(
# C:\Users\nafem\AppData\Local\Temp\ipykernel_8784\1015887474.py:47: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(
# C:\Users\nafem\AppData\Local\Temp\ipykernel_8784\1015887474.py:47: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(
# C:\Users\nafem\AppData\Local\Temp\ipykernel_8784\1015887474.py:47: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(
# C:\Users\nafem\AppData\Local\Temp\ipykernel_8784\1015887474.py:47: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(
# C:\Users\nafem\AppData\Local\Temp\ipykernel_8784\1015887474.py:47: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Configure global font settings for consistent visual presentation
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 16
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14

# Data representing mean F1-Score for various models across different feature sets
data = {
    'Feature': ['Feature 5', 'Feature 8', 'Feature 16', 'Feature 22', 'Feature 27', 'All Features'],
    'XGBoost': [0.72, 0.81, 0.92, 0.94, 0.95, 0.96],
    'Decision Tree': [0.74, 0.84, 0.90, 0.91, 0.91, 0.91],
    'Random Forest': [0.83, 0.93, 0.98, 0.99, 0.99, 0.99],
    'Extra Trees': [0.83, 0.93, 0.99, 0.99, 0.99, 0.99],
    'KNN': [0.84, 0.95, 0.99, 1.00, 1.00, 1.00],
    'ANN': [0.87, 0.99, 0.99, 0.99, 0.99, 0.99],
    'GRU': [0.88, 0.98, 0.87, 0.77, 0.86, 0.81],
    'LSTM': [0.88, 0.98, 0.74, 0.79, 0.66, 0.67],
    'Meta Learning': [0.90, 0.99, 0.99, 0.99, 0.99, 0.99]
}

# Convert dictionary into pandas DataFrame
df = pd.DataFrame(data)

# Reshape DataFrame to long format for Seaborn compatibility
df_melted = df.melt(id_vars='Feature', var_name='Model', value_name='Mean F1-Score')

# Configure Seaborn aesthetics for research-level visuals
sns.set(style="whitegrid", context="talk")  # White grid, 'talk' context for larger font sizes

# Use the 'viridis' color palette for distinct colors
palette = sns.color_palette("viridis", n_colors=len(df.columns) - 1)

# Define different line styles and markers for more sophistication
line_styles = ['-', '--', '-.', ':', '-', '--', '-.', ':', '-']  # Different line styles
markers = ['o', 's', 'D', 'v', '^', 'X', 'P', '*', 'p']  # Different markers

# Create figure and axis
plt.figure(figsize=(12, 8))

# Create line plot for mean F1-score comparison
for i, model in enumerate(df.columns[1:]):
    sns.lineplot(
        x='Feature', 
        y='Mean F1-Score', 
        data=df_melted[df_melted['Model'] == model], 
        label=model, 
        marker=markers[i], 
        linewidth=2.5, 
        linestyle=line_styles[i],
        color=palette[i]  # Use colors from the 'viridis' palette
    )

# Add plot title and axis labels
plt.title('Mean F1-Score of Models Across Feature Sets', fontsize=22, fontweight='bold', pad=20)
plt.xlabel('Feature Set', fontsize=18, labelpad=15)
plt.ylabel('Mean F1-Score', fontsize=18, labelpad=15)

# Enhance grid for better readability
plt.grid(True, which='major', linestyle='--', linewidth=0.8)
plt.grid(True, which='minor', linestyle=':', linewidth=0.5)

# Move the legend to the bottom of the plot with a box style
plt.legend(title='Model', loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3, fontsize=14, frameon=True, shadow=True)

# Adjust layout to prevent overlap and improve appearance
plt.tight_layout()

# Add extra space between the plot and the legend to avoid overlap
plt.subplots_adjust(bottom=0.25)

# Save as a high-quality PNG for research publication
plt.savefig('mean_f1_score_comparison_viridis.png', format='png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Data representing accuracy scores for various models
data = {
    'Model': ['XGB', 'DT', 'RF', 'ET', 'KNN', 'ANN', 'GRU', 'LSTM', 'Meta'],
    'Accuracy': [0.92, 0.90, 0.98, 0.99, 0.99, 0.99, 0.87, 0.75, 0.99],
    'Category': ['Machine Learning'] * 5 + ['Deep Learning'] * 4
}

# Creating a pandas DataFrame from the data
df = pd.DataFrame(data)

# Setting the plot style for a clean, professional look
sns.set(style="whitegrid")

# Creating a bar plot for model accuracy categorized by Machine Learning and Deep Learning models
plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='Accuracy', data=df, hue='Category', palette='Blues')

# Adding plot title and axis labels in Times New Roman font
plt.title('Comparison of Accuracy for Machine Learning and Deep Learning Models', fontsize=16, fontname='Times New Roman')
plt.xlabel('Model', fontsize=14, fontname='Times New Roman', labelpad=10)
plt.ylabel('Accuracy', fontsize=14, fontname='Times New Roman', labelpad=10)

# Removing minor ticks and customizing major grid for improved clarity
plt.grid(True, which='major', axis='y', linestyle='--', linewidth=0.7, color='gray')
plt.minorticks_off()

# Setting x and y axis tick font sizes
plt.xticks(fontsize=12, fontname='Times New Roman')
plt.yticks(fontsize=12, fontname='Times New Roman')

# Move the legend to the bottom and adjust layout
plt.legend(title='Category', loc='lower center', bbox_to_anchor=(0.5, -0.2), ncol=2)

# Adjusting layout to prevent label overlap
plt.tight_layout()

# Saving the figure in a lossless PDF format (best for research journals)
plt.savefig('model_accuracy_barplot_journal.pdf', format='pdf', dpi=300)

# Displaying the plot
plt.show()

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Data representing accuracy scores for various models
data = {
    'Model': ['XGB', 'DT', 'RF', 'ET', 'KNN', 'ANN', 'GRU', 'LSTM', 'Meta'],
    'Accuracy': [0.92, 0.90, 0.98, 0.99, 0.99, 0.99, 0.87, 0.75, 0.99],
    'Category': ['Machine Learning'] * 5 + ['Deep Learning'] * 4
}

# Creating a pandas DataFrame from the data
df = pd.DataFrame(data)

# Setting the plot style for a clean, professional look
sns.set(style="whitegrid")

# Creating a bar plot for model accuracy categorized by Machine Learning and Deep Learning models
plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='Accuracy', data=df, hue='Category', palette='Blues')

# Adding plot title and axis labels in Times New Roman font
plt.title('Comparison of Accuracy for Machine Learning and Deep Learning Models', fontsize=16, fontname='Times New Roman')
plt.xlabel('Model', fontsize=14, fontname='Times New Roman', labelpad=10)
plt.ylabel('Accuracy', fontsize=14, fontname='Times New Roman', labelpad=10)

# Removing minor ticks and customizing major grid for improved clarity
plt.grid(True, which='major', axis='y', linestyle='--', linewidth=0.7, color='gray')
plt.minorticks_off()

# Setting x and y axis tick font sizes
plt.xticks(fontsize=12, fontname='Times New Roman')
plt.yticks(fontsize=12, fontname='Times New Roman')

# Adjusting layout to prevent label overlap
plt.tight_layout()

# Moving the legend to the bottom without changing anything else
plt.legend(title='Category', loc='lower center', bbox_to_anchor=(0.5, -0.15), ncol=2)

# Saving the figure in a lossless PDF format (best for research journals)
plt.savefig('model_accuracy_barplot_journal.pdf', format='pdf', dpi=300)

# Displaying the plot
plt.show()

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Data representing accuracy scores for various models
data = {
    'Model': ['XGB', 'DT', 'RF', 'ET', 'KNN', 'ANN', 'GRU', 'LSTM', 'Meta'],
    'Accuracy': [0.92, 0.90, 0.98, 0.99, 0.99, 0.99, 0.87, 0.75, 0.99],
    'Category': ['Machine Learning'] * 5 + ['Deep Learning'] * 4
}

# Creating a pandas DataFrame from the data
df = pd.DataFrame(data)

# Setting the plot style for a clean, professional look
sns.set(style="whitegrid")

# Creating a bar plot for model accuracy categorized by Machine Learning and Deep Learning models
plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='Accuracy', data=df, hue='Category', palette='Blues')

# Adding plot title and axis labels in Times New Roman font
plt.title('Comparison of Accuracy for Machine Learning and Deep Learning Models', fontsize=16, fontname='Times New Roman')
plt.xlabel('Model', fontsize=14, fontname='Times New Roman', labelpad=10)
plt.ylabel('Accuracy', fontsize=14, fontname='Times New Roman', labelpad=10)

# Removing minor ticks and customizing major grid for improved clarity
plt.grid(True, which='major', axis='y', linestyle='--', linewidth=0.7, color='gray')
plt.minorticks_off()

# Setting x and y axis tick font sizes
plt.xticks(fontsize=12, fontname='Times New Roman')
plt.yticks(fontsize=12, fontname='Times New Roman')

# Adjusting layout to prevent label overlap
plt.tight_layout()

# Moving the legend to the bottom with more space to avoid overlap
plt.legend(title='Category', loc='lower center', bbox_to_anchor=(0.5, -0.3), ncol=2)

# Saving the figure in a lossless PDF format (best for research journals)
plt.savefig('model_accuracy_barplot_journal.pdf', format='pdf', dpi=300)

# Displaying the plot
plt.show()
