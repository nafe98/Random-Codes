# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
labels = ['Alternative 1', 'Alternative 2']
june_values = [220909.09, 261818.18]
laura_values = [229500.00, 247000.00]

# Set up the bar positions
x = np.arange(len(labels))
width = 0.2  # Thinner bars

# Create the bar plot
fig, ax = plt.subplots(figsize=(10, 6))  # Set figure size
bars1 = ax.bar(x - width/2, june_values, width, label='June', color='#8A2BE2')  # Violet
bars2 = ax.bar(x + width/2, laura_values, width, label='Laura', color='#1E90FF')  # Blue

# Add title and labels
ax.set_title('Year 1 Revenue Comparison for June and Laura\'s Alternatives', fontsize=18, fontweight='bold', color='#333333')
ax.set_xlabel('Approaches', fontsize=14, color='#333333')
ax.set_ylabel('Values (£)', fontsize=14, color='#333333')
ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize=12)
ax.legend(fontsize=12, frameon=True, loc='upper left')

# Add grid lines for better readability
ax.yaxis.grid(True, linestyle='--', alpha=0.7)
ax.set_axisbelow(True)  # Grid lines below bars

# Customize tick parameters
ax.tick_params(axis='both', which='major', labelsize=12)

# Set y-axis limits for better visual comparison
ax.set_ylim(0, max(max(june_values), max(laura_values)) * 1.1)

# Save the figure
plt.tight_layout()  # Adjust layout to prevent clipping
plt.savefig('revenue_comparison.png', dpi=300)  # Save as PNG with high resolution

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = ['Year 1', 'Year 2', 'Year 3', 'Year 4', 'Year 5']
june_west_revenue = [295909.09, 366169.91, 460039.16, 587612.34, 763779.31]
laura_revenue = [294500.00, 343534.85, 400617.07, 467095.18, 544548.71]

# Parameters
bar_width = 0.35
x = np.arange(len(years))  # X locations for the groups

# Create plot
fig, ax = plt.subplots()

# Plot bars with brighter colors
ax.bar(x - bar_width/2, june_west_revenue, bar_width, label='June West', color='#007BFF')  # Bright blue
ax.bar(x + bar_width/2, laura_revenue, bar_width, label='Laura', color='#6F42C1')  # Bright violet

# Labels, title, and legend
ax.set_xlabel('Years', fontsize=14)
ax.set_ylabel('Net Revenue', fontsize=14)
ax.set_title('Net Revenue Comparison for Alternative 1', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(years, fontsize=12)
ax.legend(fontsize=12)

# Adding grid for readability
ax.yaxis.grid(True, linestyle='--', alpha=0.7)

# Set y-axis limits
ax.set_ylim(0, max(max(june_west_revenue), max(laura_revenue)) * 1.1)

# Save the figure
plt.tight_layout()
plt.savefig('Net Revenue Comparison for Alternative 1.png')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for Alternative 2
years = ['Year 1', 'Year 2', 'Year 3', 'Year 4', 'Year 5']
june_west_revenue = [336818.18, 413145.82, 513981.59, 649554.44, 834907.42]
laura_revenue = [307000.00, 358630.10, 418692.44, 488592.63, 569975.74]

# Parameters
bar_width = 0.35
x = np.arange(len(years))  # X locations for the groups

# Create plot
fig, ax = plt.subplots()

# Plot bars with a different color palette
ax.bar(x - bar_width/2, june_west_revenue, bar_width, label='June West', color='#1E90FF')  # Dodger blue
ax.bar(x + bar_width/2, laura_revenue, bar_width, label='Laura', color='#8A2BE2')  # Blue violet

# Labels, title, and legend
ax.set_xlabel('Years', fontsize=14)
ax.set_ylabel('Net Revenue', fontsize=14)
ax.set_title('Net Revenue Comparison for Alternative 2', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(years, fontsize=12)
ax.legend(fontsize=12)

# Adding grid for readability
ax.yaxis.grid(True, linestyle='--', alpha=0.7)

# Set y-axis limits
ax.set_ylim(0, max(max(june_west_revenue), max(laura_revenue)) * 1.1)

# Save the figure
plt.tight_layout()
plt.savefig('Net Revenue Comparison for Alternative 2.png')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for June and Laura
categories = ['Building Works', 'Services', 'Equipment', 'Professional Fees', 'Refurbishment Costs']
june_expenditure = [22100, 20900, 86900, 6000, 0]
laura_expenditure = [22100, 20900, 86900, 6000, 25000]

# New vibrant color palette with shades of violet and blue
colors = ['#5A00E0', '#4400FF', '#7A00FF', '#0026FF', '#3500A8']

# Plotting Pie Chart for June and Laura
plt.figure(figsize=(12, 6))

# Subplot 1: June
plt.subplot(1, 2, 1)
plt.pie(june_expenditure, labels=categories, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title("June's Expenditure")

# Subplot 2: Laura
plt.subplot(1, 2, 2)
plt.pie(laura_expenditure, labels=categories, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title("Laura's Expenditure")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
labels = ['Alternative 1', 'Alternative 2']
june_values = [220909.09, 261818.18]
laura_values = [229500.00, 247000.00]

# Set up the bar positions
x = np.arange(len(labels))
width = 0.2  # Thinner bars

# Create the bar plot
fig, ax = plt.subplots(figsize=(10, 6))  # Set figure size
bars1 = ax.bar(x - width/2, june_values, width, label='June', color='#8A2BE2', edgecolor='black', linewidth=1.5)  # Violet
bars2 = ax.bar(x + width/2, laura_values, width, label='Laura', color='#1E90FF', edgecolor='black', linewidth=1.5)  # Blue

# Add title and labels
ax.set_title('Year 1 Revenue Comparison for June and Laura\'s Alternatives', fontsize=18, fontweight='bold', color='#333333')
ax.set_xlabel('Approaches', fontsize=14, color='#333333')
ax.set_ylabel('Values (£)', fontsize=14, color='#333333')
ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize=12)
ax.legend(fontsize=12, frameon=True, loc='upper left')

# Add grid lines for better readability
ax.yaxis.grid(True, linestyle='--', alpha=0.7)
ax.set_axisbelow(True)  # Grid lines below bars

# Customize tick parameters
ax.tick_params(axis='both', which='major', labelsize=12)

# Set y-axis limits for better visual comparison
ax.set_ylim(0, max(max(june_values), max(laura_values)) * 1.1)

# Format y-axis labels for thousands (e.g., 200K instead of 200000)
ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

# Add numerical labels on top of bars
for bar in bars1:
    height = bar.get_height()
    ax.annotate(f'{height:,.0f}',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom', fontsize=12, color='#333333')

for bar in bars2:
    height = bar.get_height()
    ax.annotate(f'{height:,.0f}',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom', fontsize=12, color='#333333')

# Add subtle shadow to the bars
for bar in bars1 + bars2:
    bar.set_zorder(3)

# Save the figure
plt.tight_layout()  # Adjust layout to prevent clipping
plt.savefig('revenue_comparison_enhanced.png', dpi=300)  # Save as PNG with high resolution

# Display the plot
plt.show()
